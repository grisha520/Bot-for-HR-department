# %%
# !pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
# !pip install bert_score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.8 MB/s eta 0:00:00
# ...

# %%
from evaluate import load
bertscore = load("bertscore")
predictions = ["Для оформления необходимо выполнить следующие шаги: 1. Заполнить на командировку по образцу (на диске U:\\ussc\\Шаблоны\\Кома ндировки\\ЗАЯВКА НА КОМАНДИРОВКУ_202 10630.dotx). 2. Согласовать со своим руководителем. 3. Отправить заполненную в рассылку «Командировки» (komandirovka@ussc.ru), поставить в копию своего и приложить его согласование. 4. Дождаться, когда с тобой свяжется офис, чтобы уточнить детали и места . 5. Обязательно сохранять, подтверждающие твои (билеты, посадочные талоны, ваучер в гостинице, кассовые чеки за оплату гостиницы, такси и т.д.). Они нужны для отчета. 6. По возвращению из командировки "]
references = ["«Оформление командировки» Для оформления командировки: 1. Заполни заявку на командировку по образцу 2. Согласуй командировку со своим руководителем. 3. Отправь заполненную заявку в рассылку «Командировки» (mailto:komandirovka@uss c.ru), поставь в копию своего руководителя и приложи его согласование. 4. Дождись, когда с тобой свяжется офис-менеджер, чтобы уточнить детали трансфера и места проживания. 5. Обязательно сохраняй документы, подтверждающие твои расходы (билеты, посадочные талоны, ваучер в гостинице, кассовые чеки за оплату гостиницы, такси и т.д). Они нужны для авансового отчета. 6. По возвращению из командировки отправь авансовый отчет в электронном виде в рассылку «Бухгалтерия» (mailto:buh@ussc.ru), а оригиналы документов передай в бухгалтерию на Ткачей, 23. Это нужно сделать в течение 3-х дней после возвращения из командировки."]
results = bertscore.compute(predictions=predictions, references=references, lang="ru")
print(results)

#BERTScore вычисляет точность(precision), полноту(recall) и коэффициент F1(f1), которые могут быть полезны для оценки различных задач по генерации текста.
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# {'precision': [0.8194202780723572], 'recall': [0.791999340057373], 'f1': [0.8054764866828918], 'hashcode': 'bert-base-multilingual-cased_L9_no-idf_version=0.3.12(hug_trans=4.44.2)'}

# %%
# !pip install sacrebleu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 9.1 MB/s eta 0:00:00
# ...

# %%
import sacrebleu


def calculate_bleu(hypothesis: str, reference: str) -> float:
    """
    Вычисляет BLEU-оценку между гипотезой и эталоном.

    :param hypothesis: Строка с гипотезой, которую нужно оценить.
    :param reference: Строка с эталонным переводом.
    :return: BLEU-оценка.
    """
    # Создаем список из эталона, как того требует интерфейс sacrebleu
    reference = [reference]  # sacrebleu ожидает, что все эталоны будут переданы в виде списка

    # Вычисляем BLEU-оценку
    score = sacrebleu.sentence_bleu(hypothesis, reference)

    # Возвращаем значение BLEU-оценки
    return score.score


# Пример использования
hypothesis = "Для оформления необходимо выполнить следующие шаги: 1. Заполнить на командировку по образцу (на диске U:\\ussc\\Шаблоны\\Кома ндировки\\ЗАЯВКА НА КОМАНДИРОВКУ_202 10630.dotx). 2. Согласовать со своим руководителем. 3. Отправить заполненную в рассылку «Командировки» (komandirovka@ussc.ru), поставить в копию своего и приложить его согласование. 4. Дождаться, когда с тобой свяжется офис, чтобы уточнить детали и места . 5. Обязательно сохранять, подтверждающие твои (билеты, посадочные талоны, ваучер в гостинице, кассовые чеки за оплату гостиницы, такси и т.д.). Они нужны для отчета. 6. По возвращению из командировки "
reference = "«Оформление командировки» Для оформления командировки: 1. Заполни заявку на командировку по образцу 2. Согласуй командировку со своим руководителем. 3. Отправь заполненную заявку в рассылку «Командировки» (mailto:komandirovka@uss c.ru), поставь в копию своего руководителя и приложи его согласование. 4. Дождись, когда с тобой свяжется офис-менеджер, чтобы уточнить детали трансфера и места проживания. 5. Обязательно сохраняй документы, подтверждающие твои расходы (билеты, посадочные талоны, ваучер в гостинице, кассовые чеки за оплату гостиницы, такси и т.д). Они нужны для авансового отчета. 6. По возвращению из командировки отправь авансовый отчет в электронном виде в рассылку «Бухгалтерия» (mailto:buh@ussc.ru), а оригиналы документов передай в бухгалтерию на Ткачей, 23. Это нужно сделать в течение 3-х дней после возвращения из командировки."

bleu_score = calculate_bleu(hypothesis, reference)
print(f"BLEU score: {bleu_score:.2f}")
# Out:
# BLEU score: 38.58

# %%
# !pip install sentence_transformers

# %%
from sentence_transformers import SentenceTransformer, util

# Инициализация модели SBERT
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Примеры текстов для сравнения
text1 = "Для оформления необходимо выполнить следующие шаги: 1. Заполнить на командировку по образцу (на диске U:\\ussc\\Шаблоны\\Кома ндировки\\ЗАЯВКА НА КОМАНДИРОВКУ_202 10630.dotx). 2. Согласовать со своим руководителем. 3. Отправить заполненную в рассылку «Командировки» (komandirovka@ussc.ru), поставить в копию своего и приложить его согласование. 4. Дождаться, когда с тобой свяжется офис, чтобы уточнить детали и места . 5. Обязательно сохранять, подтверждающие твои (билеты, посадочные талоны, ваучер в гостинице, кассовые чеки за оплату гостиницы, такси и т.д.). Они нужны для отчета. 6. По возвращению из командировки "
text2 = "«Оформление командировки» Для оформления командировки: 1. Заполни заявку на командировку по образцу 2. Согласуй командировку со своим руководителем. 3. Отправь заполненную заявку в рассылку «Командировки» (mailto:komandirovka@uss c.ru), поставь в копию своего руководителя и приложи его согласование. 4. Дождись, когда с тобой свяжется офис-менеджер, чтобы уточнить детали трансфера и места проживания. 5. Обязательно сохраняй документы, подтверждающие твои расходы (билеты, посадочные талоны, ваучер в гостинице, кассовые чеки за оплату гостиницы, такси и т.д). Они нужны для авансового отчета. 6. По возвращению из командировки отправь авансовый отчет в электронном виде в рассылку «Бухгалтерия» (mailto:buh@ussc.ru), а оригиналы документов передай в бухгалтерию на Ткачей, 23. Это нужно сделать в течение 3-х дней после возвращения из командировки."

# Получение векторов для текстов с помощью SBERT
embeddings1 = model.encode(text1, convert_to_tensor=True)
embeddings2 = model.encode(text2, convert_to_tensor=True)

# Вычисление косинусного сходства с помощью SBERT
cosine_similarity = util.pytorch_cos_sim(embeddings1, embeddings2).item()
print(f"Cosine Similarity (SBERT): {cosine_similarity:.4f}")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
# !pip install pyemd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.6/662.6 kB 20.1 MB/s eta 0:00:00
# ...

# %%
# !pip install torch==1.13.1+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 MB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0+cu121
#     Uninstalling torch-2.5.0+cu121:
#       Successfully uninstalled torch-2.5.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.0+cu121 requires torch==2.5.0, but you have torch 1.13.1+cpu which is incompatible.
# torchvision 0.20.0+cu121 requires torch==2.5.0, but you have torch 1.13.1+cpu which is incompatible.
# ...

# %%
# !pip install pytorch_pretrained_bert
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install moverscore
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for moverscore: filename=moverscore-1.0.3-py3-none-any.whl size=7953 sha256=998861a7f1c36be505251bf5054bc3ed12498ff8e4adb1af35dc8bc2a79c6bf0
#   Stored in directory: /root/.cache/pip/wheels/ae/b5/15/116944664c4dc1bc5316f63395d0ca11d325364b44112eb381
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26303 sha256=73f15953c42e4721a1f058e0f81f4dab41579687a43f8a31a7eabfd9437e745a
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built moverscore typing
# ...

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 11 02:01:42 2021

@author: zhao
"""
from typing import List, Union, Iterable
from itertools import zip_longest
import sacrebleu
from moverscore_v2 import word_mover_score
from collections import defaultdict
import numpy as np

def sentence_score(hypothesis: str, references: List[str], trace=0):

    idf_dict_hyp = defaultdict(lambda: 1.)
    idf_dict_ref = defaultdict(lambda: 1.)

    hypothesis = [hypothesis] * len(references)

    sentence_score = 0

    scores = word_mover_score(references, hypothesis, idf_dict_ref, idf_dict_hyp, stop_words=[], n_gram=1, remove_subwords=False)

    sentence_score = np.mean(scores)

    if trace > 0:
        print(hypothesis, references, sentence_score)

    return sentence_score

def corpus_score(sys_stream: List[str],
                     ref_streams:Union[str, List[Iterable[str]]], trace=0):

    if isinstance(sys_stream, str):
        sys_stream = [sys_stream]

    if isinstance(ref_streams, str):
        ref_streams = [[ref_streams]]

    fhs = [sys_stream] + ref_streams

    corpus_score = 0
    for lines in zip_longest(*fhs):
        if None in lines:
            raise EOFError("Source and reference streams have different lengths!")

        hypo, *refs = lines
        corpus_score += sentence_score(hypo, refs, trace=0)

    corpus_score /= len(sys_stream)

    return corpus_score

def test_corpus_score():

    refs = [['The dog bit the man.', 'It was not unexpected.', 'The man bit him first.'],
            ['The dog had bit the man.', 'No one was surprised.', 'The man had bitten the dog.']]
    sys = ['The dog bit the man.', "It wasn't surprising.", 'The man had just bitten him.']

    bleu = sacrebleu.corpus_bleu(sys, refs)
    mover = corpus_score(sys, refs)
    print(bleu.score)
    print(mover)

def test_sentence_score():

    refs = ['The dog bit the man.', 'The dog had bit the man.']
    sys = 'The dog bit the man.'

    bleu = sacrebleu.sentence_bleu(sys, refs)
    mover = sentence_score(sys, refs)

    print(bleu.score)
    print(mover)

if __name__ == '__main__':

    test_sentence_score()

    test_corpus_score()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3f48e186cb8b> in <cell line: 19>()
#      17
#      18 from moverscore_v2 import get_idf_dict
# ---> 19 idf_dict_hyp = get_idf_dict(translations)
#      20
#      21 def sentence_score(hypothesis: str, references: List[str], trace=0):
#
# NameError: name 'translations' is not defined
